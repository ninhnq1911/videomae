# %% [markdown]
# #Data loading and process

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python -m pip install -r ../requirements.txt
# !python -m pip install -e ../script/mltools

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
import sys
sys.path.append("G:\\CODE\\VIDEOMAE\\videomae\\script\\mltools\\src")

import os
os.environ["DEFAULT_COLAB_MOUNTED_FOLDER"] = "G:\\CODE\\VIDEOMAE\\videomae\\DATA"

# %%
from mltools.utl.file_util import get_resource
from mltools.ucf101_data_process import process_data_bkx, ucf101_subset_info



root_dir = get_resource("bekhoaxe")
videos_dir = os.path.join(root_dir, "videos")
output_dir = os.path.join(root_dir, "splited_videos")
process_data_bkx(
    videos_dir=videos_dir,
    output_dir=output_dir,
)

ucf101_subset_info(output_dir)
# Out:
# Dataset size:  220
# Split sizes:  154 44 22
# Copying G:/CODE/VIDEOMAE/videomae/DATA/VIDEOMAE/bekhoaxe/videos/be-khoa-xe/Rec_10-30-21_072.avi to G:/CODE/VIDEOMAE/videomae/DATA/VIDEOMAE/bekhoaxe/splited_videos/train/be-khoa-xe/Rec_10-30-21_072.avi
# Copying G:/CODE/VIDEOMAE/videomae/DATA/VIDEOMAE/bekhoaxe/videos/be-khoa-xe/Rec_11-21-21_040.avi to G:/CODE/VIDEOMAE/videomae/DATA/VIDEOMAE/bekhoaxe/splited_videos/train/be-khoa-xe/Rec_11-21-21_040.avi
# Copying G:/CODE/VIDEOMAE/videomae/DATA/VIDEOMAE/bekhoaxe/videos/be-khoa-xe/Rec_10-30-21_078.avi to G:/CODE/VIDEOMAE/videomae/DATA/VIDEOMAE/bekhoaxe/splited_videos/train/be-khoa-xe/Rec_10-30-21_078.avi
# Copying G:/CODE/VIDEOMAE/videomae/DATA/VIDEOMAE/bekhoaxe/videos/be-khoa-xe/Rec_01-06-22_002.avi to G:/CODE/VIDEOMAE/videomae/DATA/VIDEOMAE/bekhoaxe/splited_videos/train/be-khoa-xe/Rec_01-06-22_002.avi
# ...
